# %%
import cv2
import matplotlib.pyplot as plt
path=r'G:\umang sir_machine learning\umang\messy.jpg'

# %%
img=cv2.imread(path)
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
plt.show()

# %%
face=img[30:80,120:170]
plt.imshow(face)
plt.show()

# %%
ball=img[370:420,45:95]
plt.imshow(ball)
plt.show()

# %%
face=img[30:80,120:170]=ball
plt.imshow(img)
plt.show()

# %%
ball=img[370:420,45:95]=face
plt.imshow(img)
plt.show()

# %% [markdown]
# # face detection

# %%
img
